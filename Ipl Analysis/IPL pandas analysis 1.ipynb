# %%
import numpy as np
import pandas as pd

# %%
matches=pd.read_csv(r"C:\Users\raush\Downloads\ipl data analysis\matches.csv")

# %%
matches.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
matches.shape
# Out:
# (756, 18)

# %%
matches.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
matches.sample()
# Out:
#       id  season city        date                team1             team2  \
# 468  469    2014  NaN  2014-04-25  Sunrisers Hyderabad  Delhi Daredevils
#
#              toss_winner toss_decision  result  dl_applied  \
# 468  Sunrisers Hyderabad           bat  normal           0
#
#                   winner  win_by_runs  win_by_wickets player_of_match  \
# 468  Sunrisers Hyderabad            4               0        AJ Finch
#
#                                    venue    umpire1 umpire2 umpire3
# 468  Dubai International Cricket Stadium  M Erasmus  S Ravi     NaN

# %%
matches.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
matches.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
matches['city']
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 751           Mumbai
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
matches['city'].index
# Out:
# RangeIndex(start=0, stop=756, step=1)

# %%
matches['city'].values
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Hyderabad',
#        'Mumbai', 'Indore', 'Pune', 'Mumbai', 'Kolkata', 'Bangalore',
#        'Rajkot', 'Kolkata', 'Delhi', 'Mumbai', 'Bangalore', 'Delhi',
#        'Hyderabad', 'Rajkot', 'Hyderabad', 'Indore', 'Kolkata', 'Mumbai',
#        'Pune', 'Rajkot', 'Kolkata', 'Mumbai', 'Pune', 'Bangalore',
#        'Kolkata', 'Chandigarh', 'Pune', 'Rajkot', 'Chandigarh',
#        'Hyderabad', 'Mumbai', 'Pune', 'Delhi', 'Kolkata', 'Delhi',
#        'Bangalore', 'Hyderabad', 'Delhi', 'Bangalore', 'Chandigarh',
#        'Hyderabad', 'Chandigarh', 'Kanpur', 'Mumbai', 'Delhi', 'Kanpur',
#        'Kolkata', 'Pune', 'Delhi', 'Mumbai', 'Bangalore', 'Bangalore',
#        'Hyderabad', 'Bangalore', 'Chandigarh', 'Delhi', 'Mumbai',
#        'Kolkata', 'Jaipur', 'Hyderabad', 'Chennai', 'Hyderabad',
#        'Chandigarh', 'Bangalore', 'Chennai', 'Mumbai', 'Chandigarh',
#        'Bangalore', 'Kolkata', 'Delhi', 'Hyderabad', 'Jaipur', 'Chennai',
# ...

# %%
matches['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Port Elizabeth      7
# Ranchi              7
# Abu Dhabi           7
# Cape Town           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# East London         3
# Kimberley           3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
matches[['winner','player_of_match']]
# Out:
#                           winner player_of_match
# 0            Sunrisers Hyderabad    Yuvraj Singh
# 1         Rising Pune Supergiant       SPD Smith
# 2          Kolkata Knight Riders         CA Lynn
# 3                Kings XI Punjab      GJ Maxwell
# 4    Royal Challengers Bangalore       KM Jadhav
# ..                           ...             ...
# 751               Mumbai Indians       HH Pandya
# 752               Mumbai Indians        AS Yadav
# 753               Delhi Capitals         RR Pant
# 754          Chennai Super Kings    F du Plessis
# 755               Mumbai Indians       JJ Bumrah
#
# [756 rows x 2 columns]

# %%
matches.iloc[1]
# Out:
# id                                                       2
# season                                                2017
# city                                                  Pune
# date                                            2017-04-06
# team1                                       Mumbai Indians
# team2                               Rising Pune Supergiant
# toss_winner                         Rising Pune Supergiant
# toss_decision                                        field
# result                                              normal
# dl_applied                                               0
# winner                              Rising Pune Supergiant
# win_by_runs                                              0
# win_by_wickets                                           7
# player_of_match                                  SPD Smith
# venue              Maharashtra Cricket Association Stadium
# umpire1                                     A Nand Kishore
# ...

# %%
matches.iloc[1].index
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
matches.iloc[1].values
# Out:
# array([2, 2017, 'Pune', '2017-04-06', 'Mumbai Indians',
#        'Rising Pune Supergiant', 'Rising Pune Supergiant', 'field',
#        'normal', 0, 'Rising Pune Supergiant', 0, 7, 'SPD Smith',
#        'Maharashtra Cricket Association Stadium', 'A Nand Kishore',
#        'S Ravi', nan], dtype=object)

# %%
matches.iloc[1].shape
# Out:
# (18,)

# %%
matches.iloc[2:6]
# Out:
#    id  season       city        date                        team1  \
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
#
#                    team2                  toss_winner toss_decision  result  \
# 2  Kolkata Knight Riders        Kolkata Knight Riders         field  normal
# 3        Kings XI Punjab              Kings XI Punjab         field  normal
# 4       Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 5    Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
#
#    dl_applied                       winner  win_by_runs  win_by_wickets  \
# 2           0        Kolkata Knight Riders            0              10
# 3           0              Kings XI Punjab            0               6
# ...

# %%
matches.iloc[2:6].city
# Out:
# 2       Rajkot
# 3       Indore
# 4    Bangalore
# 5    Hyderabad
# Name: city, dtype: object

# %%
matches[::-1]
# Out:
#         id  season           city        date                        team1  \
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# ..     ...     ...            ...         ...                          ...
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
#
# ...

# %%
matches['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
matches['player_of_match'].value_counts().head(15)
# Out:
# CH Gayle          21
# AB de Villiers    20
# DA Warner         17
# MS Dhoni          17
# RG Sharma         17
# YK Pathan         16
# SR Watson         15
# SK Raina          14
# G Gambhir         13
# AM Rahane         12
# MEK Hussey        12
# V Kohli           12
# AD Russell        11
# A Mishra          11
# DR Smith          11
# Name: player_of_match, dtype: int64

# %%
matches[:59].player_of_match.value_counts()
# Out:
# NM Coulter-Nile      3
# BA Stokes            3
# AJ Tye               2
# N Rana               2
# SP Narine            2
# JD Unadkat           2
# Rashid Khan          2
# RV Uthappa           2
# KH Pandya            2
# Sandeep Sharma       2
# MM Sharma            1
# RR Pant              1
# SPD Smith            1
# S Dhawan             1
# KV Sharma            1
# MS Dhoni             1
# RA Tripathi          1
# RG Sharma            1
# DA Warner            1
# CA Lynn              1
# Washington Sundar    1
# AT Rayudu            1
# HV Patel             1
# LH Ferguson          1
# GJ Maxwell           1
# Yuvraj Singh         1
# G Gambhir            1
# AR Patel             1
# CH Gayle             1
# HM Amla              1
# KA Pollard           1
# MJ McClenaghan       1
# SK Raina             1
# DR Smith             1
# Mohammed Siraj       1
# KM Jadhav            1
# B Kumar              1
# CJ Anderson          1
# JJ Bumrah            1
# KS Williamson        1
# ...

# %%
matches[576:636].player_of_match.value_counts()
# Out:
# V Kohli              5
# RG Sharma            4
# AB de Villiers       4
# DA Warner            3
# AD Russell           3
# AJ Finch             3
# YK Pathan            2
# AM Rahane            2
# DR Smith             2
# B Kumar              2
# AB Dinda             2
# KH Pandya            2
# MP Stoinis           2
# CH Morris            2
# RV Uthappa           1
# MC Henriques         1
# A Mishra             1
# PA Patel             1
# SK Raina             1
# AR Patel             1
# A Zampa              1
# P Kumar              1
# Q de Kock            1
# CR Brathwaite        1
# SA Yadav             1
# MS Dhoni             1
# HM Amla              1
# A Nehra              1
# RR Pant              1
# Mustafizur Rahman    1
# SR Watson            1
# BCJ Cutting          1
# G Gambhir            1
# M Vohra              1
# KK Nair              1
# SV Samson            1
# Name: player_of_match, dtype: int64

# %%
mask=matches['city']=='Kolkata'
matches[mask]
# Out:
#         id  season     city        date                        team1  \
# 10      11    2017  Kolkata  2017-04-13              Kings XI Punjab
# 13      14    2017  Kolkata  2017-04-15        Kolkata Knight Riders
# 22      23    2017  Kolkata  2017-04-21        Kolkata Knight Riders
# 26      27    2017  Kolkata  2017-04-23        Kolkata Knight Riders
# 30      31    2017  Kolkata  2017-04-28             Delhi Daredevils
# ..     ...     ...      ...         ...                          ...
# 721  11317    2019  Kolkata    12/04/19        Kolkata Knight Riders
# 724  11320    2019  Kolkata    14/04/19        Kolkata Knight Riders
# 730  11326    2019  Kolkata    19/04/19  Royal Challengers Bangalore
# 738  11334    2019  Kolkata    25/04/19        Kolkata Knight Riders
# 742  11338    2019  Kolkata    28/04/19        Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
mask=matches['player_of_match']=='CH Gayle'
matches[mask]
# Out:
#         id  season        city        date                        team1  \
# 19      20    2017      Rajkot  2017-04-18  Royal Challengers Bangalore
# 122    123    2009      Durban  2009-04-21              Kings XI Punjab
# 257    258    2011     Kolkata  2011-04-22        Kolkata Knight Riders
# 279    280    2011   Bangalore  2011-05-06  Royal Challengers Bangalore
# 282    283    2011   Bangalore  2011-05-08         Kochi Tuskers Kerala
# 290    291    2011   Bangalore  2011-05-14        Kolkata Knight Riders
# 301    302    2011   Bangalore  2011-05-22          Chennai Super Kings
# 305    306    2011     Chennai  2011-05-27  Royal Challengers Bangalore
# 328    329    2012   Bangalore  2012-04-17                Pune Warriors
# 332    333    2012  Chandigarh  2012-04-20              Kings XI Punjab
# 359    360    2012      Mumbai  2012-05-09               Mumbai Indians
# 361    362    2012        Pune  2012-05-11  Royal Challengers Bangalore
# ...

# %%
# mask=matches['city']=='Chennai'
# match[mask]
mask=matches['city']=='Chennai'
matches[mask]['player_of_match'].value_counts()
# Out:
# MS Dhoni           5
# MEK Hussey         5
# SK Raina           4
# M Vijay            4
# BB McCullum        2
# RA Jadeja          2
# F du Plessis       2
# G Gambhir          2
# Harbhajan Singh    2
# JA Morkel          2
# S Anirudha         1
# BW Hilfenhaus      1
# J Theron           1
# DL Chahar          1
# DJ Bravo           1
# L Balaji           1
# JDP Oram           1
# SPD Smith          1
# R Ashwin           1
# WPUJC Vaas         1
# A Nehra            1
# CH Gayle           1
# MS Bisla           1
# RG Sharma          1
# ML Hayden          1
# A Kumble           1
# WP Saha            1
# Mandeep Singh      1
# HH Pandya          1
# AS Yadav           1
# RE Levi            1
# KMDN Kulasekara    1
# SR Watson          1
# SW Billings        1
# AC Gilchrist       1
# KA Pollard         1
# V Sehwag           1
# Name: player_of_match, dtype: int64

# %%
mask = matches['season'] >=2015
mask.value_counts()
# Out:
# False    458
# True     298
# Name: season, dtype: int64

# %%
mask = matches['season'] >=2015
matches[mask]['winner'].value_counts()
# Out:
# Mumbai Indians                 46
# Sunrisers Hyderabad            42
# Kolkata Knight Riders          39
# Royal Challengers Bangalore    31
# Chennai Super Kings            31
# Kings XI Punjab                26
# Delhi Daredevils               23
# Rajasthan Royals               19
# Gujarat Lions                  13
# Rising Pune Supergiant         10
# Delhi Capitals                 10
# Rising Pune Supergiants         5
# Name: winner, dtype: int64

# %%
mask1=matches["city"]=="Hyderabad"
mask2=matches["season"]>=2015
matches[mask1 & mask2]["player_of_match"].value_counts()
# Out:
# DA Warner            7
# Rashid Khan          4
# B Kumar              2
# S Dhawan             2
# KS Williamson        2
# A Joseph             1
# Mustafizur Rahman    1
# AS Rajpoot           1
# JJ Bumrah            1
# KH Pandya            1
# K Ahmed              1
# JD Unadkat           1
# J Bairstow           1
# Yuvraj Singh         1
# CH Morris            1
# K Paul               1
# AT Rayudu            1
# CA Lynn              1
# MJ McClenaghan       1
# V Kohli              1
# AB Dinda             1
# G Gambhir            1
# Name: player_of_match, dtype: int64
